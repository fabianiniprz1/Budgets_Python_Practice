# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data_file = '/Users/usermac/Documents/Education/Data Science/Python Practice/Budgets/2024-Table 1.csv'
df = pd.read_csv(data_file)

# %%
df[['Detail','Total Pay','First Pay','Second Pay']].groupby('Detail').sum(['Total Pay','First Pay','Second Pay']).sort_values(by='Total Pay',ascending=False)
# Out:
#                                    Total Pay  First Pay  Second Pay
# Detail
# Ahorro pa la moto                      34500    16500.0     18000.0
# TC Banco de Bogota                     14190      590.0     13600.0
# Credito Fondecom (fondegarantias)      10100     5000.0      5100.0
# Hipoteca                                7950      300.0      7650.0
# Comida                                  7200     3600.0      3600.0
# Alquiler                                6592     6592.0         0.0
# 💜🖤                                      3600        0.0      3600.0
# Credito Bancolombia                     3000        0.0      3000.0
# Regalos                                 2850     2550.0       300.0
# Inverciones Zukaritas                   2400     1200.0      1200.0
# MI PAGO (Tyba)                          2200     1100.0      1100.0
# Vuelos Brazil                           2000        0.0      2000.0
# Calistenia                              1920        0.0      1920.0
# ...

# %%
max_pay = np.max(df['Total Pay'])
min_pay = np.min(df['Total Pay'])

max_pay_row = df['Detail'][df['Total Pay'] == max_pay].unique()
min_pay_row = df['Detail'][df['Total Pay'] == min_pay].unique()

print(max_pay_row)
# Out:
# ['Hipoteca']
